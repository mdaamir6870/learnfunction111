# %%
print("this is my first programe")
# Out:
# this is my first programe

# %%
1+2
# Out:
# 3

# %%
3/7
# Out:
# 0.42857142857142855

# %%
a=10

# %%
aamir=4285

# %%
aamir
# Out:
# 4285

# %%
type(aamir)
# Out:
# int

# %%
b=4.4456

# %%
type(b)
# Out:
# float

# %%
c='aamir'

# %%
type(c)
# Out:
# str

# %%
d="aamir"

# %%
type(d)
# Out:
# str

# %%
e=5+6j

# %%
type(e)
# Out:
# complex

# %%
d
# Out:
# 'aamir'

# %%
c
# Out:
# 'aamir'

# %%
g=True

# %%
type(g)
# Out:
# bool

# %%
_a=45

# %%
type(_a)
# Out:
# int

# %%
a=455 
b='aamir'
c=6+7j
d=True
e=5677.786

# %%
a1=5

# %%
a+a1
# Out:
# 460

# %%
a1,b1,c1,d1,e1=5,"raj",6+5j,False,58.7

# %%
a+a1,b+b1,c+c1,d+d1,e+e1
# Out:
# (460, 'aamirraj', (12+12j), 1, 5736.486)

# %%
type(c)
# Out:
# complex

# %%
c
# Out:
# (6+7j)

# %%
c.real
# Out:
# 6.0

# %%
c.imag
# Out:
# 7.0

# %%
b='babban'

# %%
b=765.6765

# %%
a='babban'

# %%
a+'4+"6"'
# Out:
# 'babban4+"6"'

# %%
a+str(9523235723)
# Out:
# 'babban9523235723'

# %%
True+False
# Out:
# 1

# %%
True+True
# Out:
# 2

# %%
True-True
# Out:
# 0

# %%
1+True
# Out:
# 2

# %%
b
# Out:
# 765.6765

# %%
a=input('ffdvhjachjgsgshgjsjsvvvvcjfkfw')
